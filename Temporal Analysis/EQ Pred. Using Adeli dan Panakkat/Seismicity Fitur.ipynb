# %%
import os
os.chdir("/content/drive/My Drive/11_Dataset_Repository/INSTANCE/")

dataset = "https://raw.githubusercontent.com/arifadli/DatasetRepository/master/USGS/database.csv"
data = pd.read_csv(dataset)

function_filter='/content/drive/My Drive/11_Dataset_Repository/Function/Def_plot_waveform.py'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting filters
#   Downloading filters-1.3.2-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from filters) (1.15.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from filters) (2022.6)
# Collecting class-registry
#   Downloading class_registry-2.1.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from filters) (2022.6.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from filters) (2.8.2)
# Installing collected packages: class-registry, filters
# Successfully installed class-registry-2.1.2 filters-1.3.2

# %%
import numpy as np
import pandas as pd

from filter import read_data, path_list,threshold

paths = path_list()

def read_feature_1(path):
    df = read_data(path)

    df['Magnitude'] = df['Magnitude'].apply(pd.to_numeric)
    new_df = df.loc[df["Magnitude"] > threshold]
    x = new_df['Date'] + ' ' + new_df['Time']
    new_df["Datetime"] = pd.to_datetime(x, format='%Y/%m/%d %H:%M:%S.%f')
    # x = new_df['Date']
    # new_df["Date"] = pd.to_datetime(x, format='%Y/%m/%d')
    del new_df["Time"]
    groups = new_df.groupby(new_df.Datetime.dt.month).agg({'Datetime': ['first',
                                                                        'last']})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-674d10a8ebdd> in <module>
#       2 import pandas as pd
#       3
# ----> 4 from filter import read_data, path_list,threshold
#       5
#       6 paths = path_list()
#
# ModuleNotFoundError: No module named 'filter'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
