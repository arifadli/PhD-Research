# %% [markdown]
# Keterangan
# Mencari Indikator 8 Seismik (Panakkat dan Adeli) menggunakan dataset yang berasal dari USGS

# %% [markdown]
# **Import Libraray**

# %%
import numpy as np
import pandas as pd
import os
import math
from collections import Counter

# %%
#jika dari dataset github
dataset = "https://raw.githubusercontent.com/arifadli/DatasetRepository/main/USGS/database_original.csv"
df = pd.read_csv(dataset)
df.head(10)
# Out:
#         Date      Time  Latitude  Longitude        Type  Depth  Magnitude  \
# 0   1/2/1965  13:44:18    19.246    145.616  Earthquake  131.6        6.0
# 1   1/4/1965  11:29:49     1.863    127.352  Earthquake   80.0        5.8
# 2   1/5/1965  18:05:58   -20.579   -173.972  Earthquake   20.0        6.2
# 3   1/8/1965  18:49:43   -59.076    -23.557  Earthquake   15.0        5.8
# 4   1/9/1965  13:32:50    11.938    126.427  Earthquake   15.0        5.8
# 5  1/10/1965  13:36:32   -13.405    166.629  Earthquake   35.0        6.7
# 6  1/12/1965  13:32:25    27.357     87.867  Earthquake   20.0        5.9
# 7  1/15/1965  23:17:42   -13.309    166.212  Earthquake   35.0        6.0
# 8  1/16/1965  11:32:37   -56.452    -27.043  Earthquake   95.0        6.0
# 9  1/17/1965  10:43:17   -24.563    178.487  Earthquake  565.0        5.8
#
#   Magnitude Type               ID     Source Location Source Magnitude Source  \
# 0             MW     ISCGEM860706     ISCGEM          ISCGEM           ISCGEM
# 1             MW     ISCGEM860737     ISCGEM          ISCGEM           ISCGEM
# 2             MW     ISCGEM860762     ISCGEM          ISCGEM           ISCGEM
# 3             MW     ISCGEM860856     ISCGEM          ISCGEM           ISCGEM
# 4             MW     ISCGEM860890     ISCGEM          ISCGEM           ISCGEM
# 5             MW     ISCGEM860922     ISCGEM          ISCGEM           ISCGEM
# 6             MW     ISCGEM861007     ISCGEM          ISCGEM           ISCGEM
# 7             MW     ISCGEM861111     ISCGEM          ISCGEM           ISCGEM
# 8             MW  ISCGEMSUP861125  ISCGEMSUP          ISCGEM           ISCGEM
# 9             MW     ISCGEM861148     ISCGEM          ISCGEM           ISCGEM
#
#       Status
# 0  Automatic
# 1  Automatic
# 2  Automatic
# 3  Automatic
# 4  Automatic
# 5  Automatic
# 6  Automatic
# 7  Automatic
# 8  Automatic
# 9  Automatic

# %%
threshold = 4.0
file_name = dataset
Dates = []

def get_Dates():
    global file_name
    global Dates
    df = pd.read_csv(file_name)
    df = df[df.Type == "Earthquake"]
    df = df[df.Magnitude > threshold]
    df.Date = df.Date + ' '  + df.Time
    del df["Time"]
    del df["Type"]

    # Grouping Data Into Months
    df.Magnitude = df.Magnitude.apply(pd.to_numeric)
    df.Date = pd.to_datetime(df.Date, format='%m/%d/%Y %H:%M:%S')
    Dates = df.Date
    print(Dates)
    return Dates

def read_data():
    global file_name
    df = pd.read_csv(file_name)
    df = df[df.Type == "Earthquake"]
    df = df[df.Magnitude > threshold]
    df.Date = df.Date + ' '  + df.Time
    del df["Time"]
    del df["Type"]

    # Grouping Data Into Months
    df.Magnitude = df.Magnitude.apply(pd.to_numeric)
    df.Date = pd.to_datetime(df.Date, format='%m/%d/%Y %H:%M:%S')
    groups = df.groupby(df.Date.dt.year)
    return groups

def read_frame():
    global file_name
    df = pd.read_csv(file_name)
    df = df[df.Type == "Earthquake"]
    df.Date = df.Date + ' '  + df.Time
    del df["Time"]
    del df["Type"]

    # Grouping Data Into Months
    df.Magnitude = df.Magnitude.apply(pd.to_numeric)
    df.Date = pd.to_datetime(df.Date, format='%m/%d/%Y %H:%M:%S')
    return df

# %%
def read_feature_1():
    df = read_data()
    df['Magnitude'] = df['Magnitude'].apply(pd.to_numeric)
    new_df = df.loc[df["Magnitude"] > threshold]
    x = new_df['Date'] + ' ' + new_df['Time']
    new_df["Datetime"] = pd.to_datetime(x, format='%m/%d/%Y %H:%M:%S')
    # x = new_df['Date']
    # new_df["Date"] = pd.to_datetime(x, format='%Y/%m/%d')
    del new_df["Time"]
    groups = new_df.groupby(new_df.Datetime.dt.month).agg({'Datetime': ['first',
                                                                        'last']})

    days = (groups.Datetime['last'] - groups.Datetime['first'])
    groups['seconds'] = days / np.timedelta64(1, 's')
    groups['days'] = days
    #print(days.dt.days)
    return np.float64(days.dt.days)

def read_full_feature_1():
    Time = []
    for path in paths:
        Time.append(read_feature_1(path))
    return np.array(Time)

# %%
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0        1/2/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1        1/4/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2        1/5/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3        1/8/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4        1/9/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23404  12/28/2016   8:22:12   38.3917  -118.8941  Earthquake   12.30
# 23405  12/28/2016   9:13:47   38.3777  -118.8957  Earthquake    8.80
# 23406  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23407  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23408  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Magnitude Magnitude Type            ID  Source Location Source  \
# 0            6.0             MW  ISCGEM860706  ISCGEM          ISCGEM
# 1            5.8             MW  ISCGEM860737  ISCGEM          ISCGEM
# 2            6.2             MW  ISCGEM860762  ISCGEM          ISCGEM
# 3            5.8             MW  ISCGEM860856  ISCGEM          ISCGEM
# 4            5.8             MW  ISCGEM860890  ISCGEM          ISCGEM
# ...          ...            ...           ...     ...             ...
# 23404        5.6             ML    NN00570710      NN              NN
# 23405        5.5             ML    NN00570744      NN              NN
# 23406        5.9            MWW    US10007NAF      US              US
# 23407        6.3            MWW    US10007NL0      US              US
# 23408        5.5             MB    US10007NTD      US              US
#
#       Magnitude Source     Status
# 0               ISCGEM  Automatic
# 1               ISCGEM  Automatic
# 2               ISCGEM  Automatic
# 3               ISCGEM  Automatic
# 4               ISCGEM  Automatic
# ...                ...        ...
# 23404               NN   Reviewed
# 23405               NN   Reviewed
# 23406               US   Reviewed
# 23407               US   Reviewed
# 23408               US   Reviewed
#
# [23409 rows x 13 columns]

# %%
print('>>> Import Completed\n >>> Reading Feature 1')
Feature_1 = read_feature_1()
# Out:
# >>> Import Completed
#  >>> Reading Feature 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-265e0cdb39d0> in <module>
#       1 print('>>> Import Completed\n >>> Reading Feature 1')
# ----> 2 Feature_1 = read_feature_1()
#
# <ipython-input-26-808a854679f6> in read_feature_1()
#       1 def read_feature_1():
#       2     df = read_data()
# ----> 3     df['Magnitude'] = df['Magnitude'].apply(pd.to_numeric)
#       4     new_df = df.loc[df["Magnitude"] > threshold]
#       5     x = new_df['Date'] + ' ' + new_df['Time']
#
# TypeError: 'DataFrameGroupBy' object does not support item assignment

# %%
df['Magnitude'] = df['Magnitude'].apply(pd.to_numeric)
new_df = df.loc[df["Magnitude"] > threshold]
# x = new_df['Date']+' '+new_df['Time']
# new_df["Datetime"] = pd.to_datetime(x ,format='%Y/%m/%d %H:%M:%S.%f')
x = new_df['Date']
new_df["Date"] = pd.to_datetime(x, format='%m/%d/%Y')
del new_df["Time"]
groups = new_df.groupby(
    new_df.Date.dt.month) 

#print(groups['Magnitude'].mean())
groups['Magnitude'].mean()
new_df
# Out:
#             Date  Latitude  Longitude        Type   Depth  Magnitude  \
# 0     1965-01-02   19.2460   145.6160  Earthquake  131.60        6.0
# 1     1965-01-04    1.8630   127.3520  Earthquake   80.00        5.8
# 2     1965-01-05  -20.5790  -173.9720  Earthquake   20.00        6.2
# 3     1965-01-08  -59.0760   -23.5570  Earthquake   15.00        5.8
# 4     1965-01-09   11.9380   126.4270  Earthquake   15.00        5.8
# ...          ...       ...        ...         ...     ...        ...
# 23404 2016-12-28   38.3917  -118.8941  Earthquake   12.30        5.6
# 23405 2016-12-28   38.3777  -118.8957  Earthquake    8.80        5.5
# 23406 2016-12-28   36.9179   140.4262  Earthquake   10.00        5.9
# 23407 2016-12-29   -9.0283   118.6639  Earthquake   79.00        6.3
# 23408 2016-12-30   37.3973   141.4103  Earthquake   11.94        5.5
#
#       Magnitude Type            ID  Source Location Source Magnitude Source  \
# 0                 MW  ISCGEM860706  ISCGEM          ISCGEM           ISCGEM
# 1                 MW  ISCGEM860737  ISCGEM          ISCGEM           ISCGEM
# 2                 MW  ISCGEM860762  ISCGEM          ISCGEM           ISCGEM
# 3                 MW  ISCGEM860856  ISCGEM          ISCGEM           ISCGEM
# 4                 MW  ISCGEM860890  ISCGEM          ISCGEM           ISCGEM
# ...              ...           ...     ...             ...              ...
# 23404             ML    NN00570710      NN              NN               NN
# 23405             ML    NN00570744      NN              NN               NN
# 23406            MWW    US10007NAF      US              US               US
# 23407            MWW    US10007NL0      US              US               US
# 23408             MB    US10007NTD      US              US               US
#
#           Status
# 0      Automatic
# 1      Automatic
# 2      Automatic
# 3      Automatic
# 4      Automatic
# ...          ...
# 23404   Reviewed
# 23405   Reviewed
# 23406   Reviewed
# 23407   Reviewed
# 23408   Reviewed
#
# [23409 rows x 12 columns]
